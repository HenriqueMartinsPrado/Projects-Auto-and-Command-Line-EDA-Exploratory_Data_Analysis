# %% [markdown]
# <h3>Automatizando a Análise Exploratória de Dados</h3>
# <h4>Autor: Henrique Martins Prado</h4>

# %%
import pandas as pd
import pandas_profiling

# %% [markdown]
# <h4>Carregando Datasets</h4>

# %%
carros_olx = pd.read_csv(r'C:\Users\hik_m\Documents\Jornada do Conhecimento\Projetos\EDA-Exploratory_Data_Analysis\datasets\Dataset_Carros_OLX.csv', sep=';')
carros_olx.head()
# Out:
#         Valor                                             Titulo  \
# 0   R$ 64.500  FIORINO 2019/2020 1.4 MPI FURGÃO HARD WORKING ...
# 1   R$ 83.900  COROLLA 2019/2019 1.8 GLI UPPER 16V FLEX 4P AU...
# 2   R$ 29.800   Golf GLX 1995 com 49.300km. Original e impecável
# 3  R$ 137.267  Jeep Renegade Trailhawk Turbo Diesel At 2.0 4x...
# 4   R$ 38.900                      Hyundai HB20 HB20 1.0 Comfort
#
#   Quilometragem Cambio Combustivel                Localizacao
# 0        38.450     km        Flex  São Paulo, Vila Guilherme
# 1        37.744     km        Flex  São Paulo, Vila Guilherme
# 2        49.300     km    Gasolina          Osasco, Jaguaribe
# 3             0     km      Diesel      São Paulo, Casa Verde
# 4        40.000     km        Flex    São Paulo, Moinho Velho

# %%
credit_fraud_det = pd.read_csv(r'C:\Users\hik_m\Documents\Jornada do Conhecimento\Projetos\EDA-Exploratory_Data_Analysis\datasets\Kaggle\3DCredit Card Fraud Detection\train.csv')
credit_fraud_det.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_default = pd.read_csv(r'C:\Users\hik_m\Documents\Jornada do Conhecimento\Projetos\EDA-Exploratory_Data_Analysis\datasets\Kaggle\Default of Credit Card Clients\Credit_Card_train.csv')
credit_default.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
email_spam_detection = pd.read_csv(r'C:\Users\hik_m\Documents\Jornada do Conhecimento\Projetos\EDA-Exploratory_Data_Analysis\datasets\Kaggle\Outbound email spam detection using Unsupervised\MailCountLog.csv')
email_spam_detection.head()
# Out:
#          TimeStamp                              EntityId    MachineName  \
# 0  12/4/2019 13:14  0de16bb3-94aa-4f54-e4f6-08d778bbe2b6  CH2PR04MB6572
# 1  12/4/2019 16:25  dd6c22e5-cb71-486a-ee5c-08d778d695c4  BY5PR05MB6916
# 2  12/4/2019 11:05  86214b1b-2642-4cd7-fad5-08d778a9f148  VI1P193MB0448
# 3  12/4/2019 15:55  61eb22b4-4abb-43de-a5f4-08d778d25b73  BN6PR03MB3346
# 4  12/4/2019 13:02  576066b2-f3b5-447b-2936-08d778ba28c9  AM6PR08MB3317
#
#                                TenantId                                UserId  \
# 0  edd56ed8-70ca-4351-83cb-4128876592e9  00000483-de56-414f-97d1-b72b620f8c58
# 1  7d700ef5-a0c9-432a-a2ca-fc29c16f2d00  000004cd-3689-463a-ba8e-36372e58773f
# 2  de1535eb-16df-4359-90f1-75da64631829  00000f41-9298-4367-b8e4-b75332d537db
# 3  d13a3cbd-e4ce-45e1-91c2-98859a236439  00001702-e253-4739-b720-b55502131ba7
# 4  aa3c372d-0013-4bdc-b272-204afc0088b6  00001e01-7559-4f4c-9fc1-7076769d0c77
#
# ...

# %%
stock_market = pd.read_csv(r'C:\Users\hik_m\Documents\Jornada do Conhecimento\Projetos\EDA-Exploratory_Data_Analysis\datasets\Kaggle\The Winton Stock Market Challenge\train.csv')
stock_market
# Out:
#           Id  Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  \
# 0          1        NaN        NaN        NaN        NaN        8.0
# 1          2        NaN        NaN        NaN        NaN        3.0
# 2          3        NaN  -0.696727   0.739591  -0.167928        9.0
# 3          4        NaN  -0.694350   1.568248   0.479073        5.0
# 4          5        6.0  -1.736489   2.765531   1.245280        7.0
# ...      ...        ...        ...        ...        ...        ...
# 39995  39996        NaN        NaN   0.822371        NaN        1.0
# 39996  39997        NaN   0.747556  -0.489418  -0.267193       10.0
# 39997  39998        NaN        NaN  -0.914701  -1.013004        2.0
# 39998  39999        NaN  -0.021457   1.021284        NaN        3.0
# 39999  40000        NaN   1.093868  -0.677391  -0.604479        7.0
#
#        Feature_6  Feature_7  Feature_8  Feature_9  ...   Ret_175   Ret_176  \
# ...

# %%
titanic = pd.read_csv(r'C:\Users\hik_m\Documents\Jornada do Conhecimento\Projetos\EDA-Exploratory_Data_Analysis\datasets\Kaggle\Titanic Machine Learning from Disaster\train.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# <h4>Pandas Profiling</h4>

# %%
carros_olx.profile_report()
profile_carros_olx = carros_olx.profile_report(title='EDA - Pandas Profiling - Carros OLX')
profile_carros_olx.to_file(output_file=r'C:\Users\hik_m\Documents\Jornada do Conhecimento\Projetos\EDA-Exploratory_Data_Analysis\datasets\EDA - Pandas Profiling - Carros OLX.html')

# %%
credit_fraud_det.profile_report()
profile_credit_fraud_det = credit_fraud_det.profile_report(title='EDA - Pandas Profiling - Credict Card Fraud Detection')
profile_credit_fraud_det.to_file(output_file=r'C:\Users\hik_m\Documents\Jornada do Conhecimento\Projetos\EDA-Exploratory_Data_Analysis\datasets\Kaggle\3DCredit Card Fraud Detection\EDA - Pandas Profiling - Credict Card Fraud Detection.html')

# %%
credit_default.profile_report()
profile_credit_default = credit_default.profile_report(title='EDA - Pandas Profiling - Default of Credit Card Clients')
profile_credit_default.to_file(output_file=r'C:\Users\hik_m\Documents\Jornada do Conhecimento\Projetos\EDA-Exploratory_Data_Analysis\datasets\Kaggle\Default of Credit Card Clients\EDA - Pandas Profiling - Default of Credit Card Clients.html')

# %%
email_spam_detection.profile_report()
profile_email_spam_detection = email_spam_detection.profile_report(title='EDA - Pandas Profiling - Outbound email spam detection using Unsupervised')
profile_email_spam_detection.to_file(output_file=r'C:\Users\hik_m\Documents\Jornada do Conhecimento\Projetos\EDA-Exploratory_Data_Analysis\datasets\Kaggle\Outbound email spam detection using Unsupervised\EDA - Pandas Profiling - Outbound email spam detection using Unsupervised.html')

# %%
#stock_market.profile_report()
#profile_stock_market = stock_market.profile_report(title='EDA - Pandas Profiling - The Winton Stock Market Challenge')
#profile_stock_market.to_file(output_file=r'C:\Users\hik_m\Documents\Jornada do Conhecimento\Projetos\EDA-Exploratory_Data_Analysis\datasets\Kaggle\The Winton Stock Market Challenge\EDA - Pandas Profiling - The Winton Stock Market Challenge.html')

# %%
titanic.profile_report()
profile_titanic = titanic.profile_report(title='EDA - Pandas Profiling - Titanic Machine Learning from Disaster')
profile_titanic.to_file(output_file=r'C:\Users\hik_m\Documents\Jornada do Conhecimento\Projetos\EDA-Exploratory_Data_Analysis\datasets\Kaggle\Titanic Machine Learning from Disaster\EDA - Pandas Profiling - Titanic Machine Learning from Disaster.html')

# %% [markdown]
# <h4>Sweetviz</h4>

# %%
import sweetviz as sv

# %%
sweet_report_carros_olx = sv.analyze(carros_olx)
sweet_report_carros_olx.show_html(r'C:\Users\hik_m\Documents\Jornada do Conhecimento\Projetos\EDA-Exploratory_Data_Analysis\datasets\EDA - Sweetviz - Carros OLX.html')
# Out:
# :FEATURES DONE:                    |                     | [  0%]   00:00  -> (00:00 left)
# :PAIRWISE DONE:                    |█████████████████████| [100%]   00:00  -> (00:00 left)
# Creating Associations graph... DONE!

# %%
sweet_report_credit_fraud_det = sv.analyze(credit_fraud_det)
sweet_report_credit_fraud_det.show_html(r'C:\Users\hik_m\Documents\Jornada do Conhecimento\Projetos\EDA-Exploratory_Data_Analysis\datasets\Kaggle\3DCredit Card Fraud Detection\EDA - Sweetviz - Credict Card Fraud Detection.html')
# Out:
# :FEATURES DONE:                    |                     | [  0%]   00:33  -> (00:00 left)
# :PAIRWISE DONE:                    |█████████████████████| [100%]   00:09  -> (00:00 left)
# Creating Associations graph... DONE!

# %%
#sweet_report_email_spam_detection = sv.analyze(email_spam_detection)
#sweet_report_email_spam_detection.show_html(r'C:\Users\hik_m\Documents\Jornada do Conhecimento\Projetos\EDA-Exploratory_Data_Analysis\datasets\Kaggle\Outbound email spam detection using Unsupervised\EDA - Sweetviz - Outbound email spam detection using Unsupervised.html')

# %%
sweet_report_stock_market = sv.analyze(stock_market)
sweet_report_stock_market.show_html(r'C:\Users\hik_m\Documents\Jornada do Conhecimento\Projetos\EDA-Exploratory_Data_Analysis\datasets\Kaggle\The Winton Stock Market Challenge\EDA - Sweetviz - The Winton Stock Market Challenge.html')
# Out:
#                                    |                         | [  0%]   00:00  -> (? left)
#
# Summarizing dataframe:             |                         | [  0%]   00:00  -> (? left)
#
# Summarizing dataframe:             |                     | [  0%]   00:01  -> (05:12 left)
#
# :Id:                               |▏                    | [  1%]   00:01  -> (05:10 left)
#
# :Id:                               |▎                    | [  1%]   00:02  -> (04:11 left)
#
# :Feature_1:                        |▎                    | [  1%]   00:02  -> (04:11 left)
#
# :Feature_1:                        |▍                    | [  2%]   00:02  -> (03:17 left)
#
# :Feature_2:                        |▍                    | [  2%]   00:02  -> (03:17 left)
#
# :Feature_2:                        |▍                    | [  2%]   00:03  -> (02:59 left)
#
# :Feature_3:                        |▍                    | [  2%]   00:03  -> (02:59 left)
#
# ...

# %%
sweet_report_titanic = sv.analyze(titanic)
sweet_report_titanic.show_html(r'C:\Users\hik_m\Documents\Jornada do Conhecimento\Projetos\EDA-Exploratory_Data_Analysis\datasets\Kaggle\Titanic Machine Learning from Disaster\EDA - Sweetviz - Titanic.html')
# Out:
# :FEATURES DONE:                    |                     | [  0%]   00:04  -> (00:00 left)
# :PAIRWISE DONE:                    |█████████████████████| [100%]   00:00  -> (00:00 left)
# Creating Associations graph... DONE!

# %% [markdown]
# <h5>Comparando 2 dataset utilzando o Sweetviz</h5>

# %%
comparacao_titanic = sv.compare(titanic[102:], titanic[:102])
comparacao_titanic.show_html(r'C:\Users\hik_m\Documents\Jornada do Conhecimento\Projetos\EDA-Exploratory_Data_Analysis\datasets\Kaggle\Titanic Machine Learning from Disaster\EDA - Sweetviz - Titanic - Comparacao.html')
# Out:
#                                    |                         | [  0%]   00:00  -> (? left)
#
# Summarizing dataframe:             |                         | [  0%]   00:00  -> (? left)
#
# :PassengerId:                      |███▏                 | [ 15%]   00:00  -> (00:00 left)
#
# :PassengerId:                      |████▊                | [ 23%]   00:00  -> (00:02 left)
#
# :Survived:                         |████▊                | [ 23%]   00:00  -> (00:02 left)
#
# :Survived:                         |██████▍              | [ 31%]   00:00  -> (00:02 left)
#
# :Pclass:                           |██████▍              | [ 31%]   00:00  -> (00:02 left)
#
# :Pclass:                           |████████             | [ 38%]   00:01  -> (00:02 left)
#
# :Name:                             |████████             | [ 38%]   00:01  -> (00:02 left)
#
# :Sex:                              |█████████▋           | [ 46%]   00:01  -> (00:02 left)
#
# ...

# %% [markdown]
# <h4>Autoviz</h4>

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()
# Out:
# Imported AutoViz_Class version: 0.0.72. Call using:
#     from autoviz.AutoViz_Class import AutoViz_Class
#     AV = AutoViz_Class()
#     AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=0,
#                             lowess=False,chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30)
#
# To remove previous versions, perform 'pip uninstall autoviz'

# %%
autoviz_titanic = AV.AutoViz(r'C:\Users\hik_m\Documents\Jornada do Conhecimento\Projetos\EDA-Exploratory_Data_Analysis\datasets\Kaggle\Titanic Machine Learning from Disaster\train.csv')
# Out:
# Shape of your Data Set: (891, 12)
# Classifying variables in data set...
#     12 Predictors classified...
#         This does not include the Target column(s)
#     4 variables removed since they were ID or low-information variables
# Number of All Scatter Plots = 3
# Could not draw Violin Plot
# Time to run AutoViz (in seconds) = 7.727

# %%
# Utilizando o AutoViz eu posso explicitar minha variável dependente para ser referênciada pelas demais variáveis independentes
autoviz_titanic_survived = AV.AutoViz(r'C:\Users\hik_m\Documents\Jornada do Conhecimento\Projetos\EDA-Exploratory_Data_Analysis\datasets\Kaggle\Titanic Machine Learning from Disaster\train.csv', depVar='Survived')
# Out:
# Shape of your Data Set: (891, 12)
# Classifying variables in data set...
#     11 Predictors classified...
#         This does not include the Target column(s)
#     4 variables removed since they were ID or low-information variables
# Total Number of Scatter Plots = 3
# Nothing to add Plot not being added
# All plots done
# Time to run AutoViz (in seconds) = 6.436
